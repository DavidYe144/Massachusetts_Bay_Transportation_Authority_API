# %% [markdown]
# <h1>Module 16 Project Template</h1>

# %% [markdown]
# Use the code below to help you analyze the data returned by the MBTA API:

# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 12,
#                 "direction_id": 0,
#                 "label": "1918",
#                 "latitude": 42.34328908,
#                 "longitude": -71.08543556,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:43-04:00"
#             },
#             "id": "y1918",
#             "links": {
#                 "self": "/vehicles/y1918"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "91",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51040453",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 17,
#                 "direction_id": 0,
#                 "label": "1842",
#                 "latitude": 42.36284487,
#                 "longitude": -71.09935846,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:40-04:00"
#             },
#             "id": "y1842",
#             "links": {
#                 "self": "/vehicles/y1842"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "101",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51040454",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 226,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 12,
#                 "direction_id": 1,
#                 "label": "1838",
#                 "latitude": 42.34299276,
#                 "longitude": -71.08479893,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:46-04:00"
#             },
#             "id": "y1838",
#             "links": {
#                 "self": "/vehicles/y1838"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "91",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51040486",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 49,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": null,
#                 "direction_id": 1,
#                 "label": "1797",
#                 "latitude": 42.33693444,
#                 "longitude": -71.08937736,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:47-04:00"
#             },
#             "id": "y1797",
#             "links": {
#                 "self": "/vehicles/y1797"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": null
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51040449",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 40,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 22,
#                 "direction_id": 1,
#                 "label": "1781",
#                 "latitude": 42.33206769,
#                 "longitude": -71.08176224,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:47-04:00"
#             },
#             "id": "y1781",
#             "links": {
#                 "self": "/vehicles/y1781"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "62",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51041489",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1735",
#                 "latitude": 42.32979452,
#                 "longitude": -71.08351832,
#                 "occupancy_status": null,
#                 "speed": null,
#                 "updated_at": "2022-03-27T21:27:26-04:00"
#             },
#             "id": "y1735",
#             "links": {
#                 "self": "/vehicles/y1735"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51040455",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51040449",
#             "links": {
#                 "self": "/trips/51040449"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C09-31",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51040453",
#             "links": {
#                 "self": "/trips/51040453"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-4",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51040454",
#             "links": {
#                 "self": "/trips/51040454"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-10",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51040455",
#             "links": {
#                 "self": "/trips/51040455"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-2",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51040486",
#             "links": {
#                 "self": "/trips/51040486"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51041489",
#             "links": {
#                 "self": "/trips/51041489"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringSunday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }

# %% [markdown]
# Use the code below to read the data from your MySQL database and store it in a pandas dataframe.
#
# You you need to install pymysql to run the code:
#
# pip install pymysql

# %%
import os
import pymysql
import pandas as pd

host = '127.0.0.1'
port = '3307'
user = 'root'
password = 'root'
database = 'MBTAdb'

conn = pymysql.connect(
    host=host,
    port=int(3307),
    user="root",
    passwd=password,
    db=database,
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM mbta_buses",
    conn)

df.tail(10)
# Out:
#       record_num  route_number     id  bearing   latitude  longitude  \
# 6514        6515             1  y1838        0  42.349117 -71.088595
# 6515        6516             1  y1797        0  42.336468 -71.089875
# 6516        6517             1  y1781      140  42.337413 -71.078135
# 6517        6518             1  y1735       90  42.329800 -71.083510
# 6518        6519             1  y1918      323  42.334931 -71.074954
# 6519        6520             1  y1842      301  42.349903 -71.088966
# 6520        6521             1  y1838      128  42.348899 -71.088441
# 6521        6522             1  y1797        0  42.336489 -71.089874
# 6522        6523             1  y1781      137  42.336595 -71.077222
# 6523        6524             1  y1735       90  42.329800 -71.083510
#
#      current_status  current_stop_sequence  direction_id label  \
# 6514  IN_TRANSIT_TO                   12.0             1  1838
# 6515  IN_TRANSIT_TO                    NaN             1  1797
# 6516  IN_TRANSIT_TO                   17.0             1  1781
# 6517  IN_TRANSIT_TO                    1.0             0  1735
# 6518  IN_TRANSIT_TO                    7.0             0  1918
# 6519  IN_TRANSIT_TO                   14.0             0  1842
# 6520  IN_TRANSIT_TO                   12.0             1  1838
# 6521  IN_TRANSIT_TO                    NaN             1  1797
# 6522  IN_TRANSIT_TO                   17.0             1  1781
# 6523  IN_TRANSIT_TO                    1.0             0  1735
#
#           occupancy_status speed          updated_at
# 6514   FEW_SEATS_AVAILABLE  None 2022-03-28 01:21:42
# 6515  MANY_SEATS_AVAILABLE  None 2022-03-28 01:21:48
# 6516  MANY_SEATS_AVAILABLE  None 2022-03-28 01:21:47
# 6517                  None  None 2022-03-28 01:21:29
# 6518  MANY_SEATS_AVAILABLE  None 2022-03-28 01:21:56
# 6519   FEW_SEATS_AVAILABLE  None 2022-03-28 01:21:57
# 6520   FEW_SEATS_AVAILABLE  None 2022-03-28 01:21:54
# 6521  MANY_SEATS_AVAILABLE  None 2022-03-28 01:21:54
# 6522  MANY_SEATS_AVAILABLE  None 2022-03-28 01:21:56
# 6523                  None  None 2022-03-28 01:21:29

# %% [markdown]
# The code below saves the data as a csv file to the local directory as a backup.

# %%
df.to_csv('mbta.csv')

# %% [markdown]
# <h1>What is the average time it takes for a bus to complete the route</h1>

# %% [markdown]
# <h1>Provide a Visualization based on the data</h1>

# %% [markdown]
# <h1>Give an estimate of the speed of the bus from current_stop_sequence = 1 to the last  current_stop_sequence. </h1>
#
# Note: You can use the haversine Python library to calculate the distance between two points, given two longitude and latitude coordinates.
